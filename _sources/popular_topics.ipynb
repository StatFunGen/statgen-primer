# %% [markdown]
# # Popular Topics in Statistical Genetics
#
# | Popular Topic | Available Resource |
# |---------------|-------------------|
# | **GWAS Quality Control** | [genotype coding](https://statfungen.github.io/statgen-primer/genotype_coding.html) |
# | | [minor allele frequency](https://statfungen.github.io/statgen-primer/minor_allele_frequency.html) |
# |  | [Hardy-Weinberg equilibrium](https://statfungen.github.io/statgen-primer/Hardy_Weinberg_equilibrium.html) |
# | **GWAS Basics** | [ordinary least squares](https://statfungen.github.io/statgen-primer/ordinary_least_squares.html) |
# | | [summary statistics](https://statfungen.github.io/statgen-primer/summary_statistics.html) |
# | | [p value](https://statfungen.github.io/statgen-primer/p_value.html) |
# | **Case-control GWAS** | [odds ratio](https://statfungen.github.io/statgen-primer/odds_ratio.html) |
# | | [summary statistics](https://statfungen.github.io/statgen-primer/summary_statistics.html) |
# | **Conditional or Joint Analysis** | [marginal joint effects](https://statfungen.github.io/statgen-primer/marginal_joint_effects.html) |
# | **Fine Mapping** | [linkage disequilibrium](https://statfungen.github.io/statgen-primer/linkage_disequilibrium.html) |
# | | [summary statistics](https://statfungen.github.io/statgen-primer/summary_statistics.html) |
# | | [Bayes factor](https://statfungen.github.io/statgen-primer/Bayes_factor.html) |
# | **Fine Mapping/Colocalization** | [Bayesian model comparison](https://statfungen.github.io/statgen-primer/Bayesian_model_comparison.html) |
# | **Meta-Analysis** | [meta analysis fixed effect](https://statfungen.github.io/statgen-primer/meta_analysis_fixed_effect.html) |
# | | [meta analysis random effect](https://statfungen.github.io/statgen-primer/meta_analysis_random_effect.html) |
# | **Multi-trait Association** | [Bayesian multivariate normal mean model](https://statfungen.github.io/statgen-primer/Bayesian_multivariate_normal_mean_model.html) |
# | **Cross-ancestry Association** | [Bayesian multivariate normal mean model](https://statfungen.github.io/statgen-primer/Bayesian_multivariate_normal_mean_model.html) |
# | **Enrichment Analysis** | [odds ratio](https://statfungen.github.io/statgen-primer/odds_ratio.html) |
# | **LD Score Regression** | [linkage disequilibrium](https://statfungen.github.io/statgen-primer/linkage_disequilibrium.html) |
# | | [linkage disequilibrium score](https://statfungen.github.io/statgen-primer/linkage_disequilibrium_score.html) |
# | **Heritability** | [proportion of variance explained](https://statfungen.github.io/statgen-primer/proportion_of_variance_explained.html) |
# | | [linkage disequilibrium score](https://statfungen.github.io/statgen-primer/linkage_disequilibrium_score.html) |
# | **Kinship/Relatedness** | [genetic relationship matrix](https://statfungen.github.io/statgen-primer/genetic_relationship_matrix.html) |
# | **Mendelian Randomization** | [confounder](https://statfungen.github.io/statgen-primer/confounder.html) |
# | | [collider](https://statfungen.github.io/statgen-primer/collider.html) |
# | | [mediator](https://statfungen.github.io/statgen-primer/mediator.html) |
# | **TWAS** | [mediator](https://statfungen.github.io/statgen-primer/mediator.html) |
# | | [marginal joint effects](https://statfungen.github.io/statgen-primer/marginal_joint_effects.html) |
# | **Mixed Effects Models** | [linear mixed model](https://statfungen.github.io/statgen-primer/linear_mixed_model.html) |
# | **Genetic Correlation** | [Bayesian multivariate normal mean model](https://statfungen.github.io/statgen-primer/Bayesian_multivariate_normal_mean_model.html) |
# | | [linkage disequilibrium score](https://statfungen.github.io/statgen-primer/linkage_disequilibrium_score.html) |
# | **Population Stratification** | [random effect](https://statfungen.github.io/statgen-primer/random_effect.html) |
# | | [linear mixed model](https://statfungen.github.io/statgen-primer/linear_mixed_model.html) |
# | | [confounder](https://statfungen.github.io/statgen-primer/confounder.html) |
# | **Pleiotropy/Colocalization** | [Bayesian multivariate normal mean model](https://statfungen.github.io/statgen-primer/Bayesian_multivariate_normal_mean_model.html) |
# | | [Bayesian mixture model](https://statfungen.github.io/statgen-primer/Bayesian_mixture_model.html) |
# | | [Bayesian model comparison](https://statfungen.github.io/statgen-primer/Bayesian_model_comparison.html) |
# | **Interaction and Epistasis** | [proportion of variance explained](https://statfungen.github.io/statgen-primer/proportion_of_variance_explained.html) |
# | | [ordinary least squares](https://statfungen.github.io/statgen-primer/ordinary_least_squares.html) |
# | **Variance Components** | [proportion of variance explained](https://statfungen.github.io/statgen-primer/proportion_of_variance_explained.html) |
# | **Bayesian GWAS** | [Bayesian frequentist](https://statfungen.github.io/statgen-primer/Bayesian_frequentist.html) |
# | | [Bayes rule](https://statfungen.github.io/statgen-primer/Bayes_rule.html) |
# | | [Bayesian normal mean model](https://statfungen.github.io/statgen-primer/Bayesian_normal_mean_model.html) |
# | **Genetic Architecture** | [linkage disequilibrium](https://statfungen.github.io/statgen-primer/linkage_disequilibrium.html) |
# | | [linkage disequilibrium score](https://statfungen.github.io/statgen-primer/linkage_disequilibrium_score.html) |
# | | [proportion of variance explained](https://statfungen.github.io/statgen-primer/proportion_of_variance_explained.html) |
# | | [Bayesian mixture model](https://statfungen.github.io/statgen-primer/Bayesian_mixture_model.html) |
# | **Polygenic Risk Scores** | [proportion of variance explained](https://statfungen.github.io/statgen-primer/proportion_of_variance_explained.html) |
# | | [ordinary least squares](https://statfungen.github.io/statgen-primer/ordinary_least_squares.html) |
